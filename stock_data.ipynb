# %%
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

# %%
data = pd.read_parquet("spx_stock_prices_master.parquet")
data
# Out:
#            cusip   permno   permco   issuno  hexcd  hsiccd        date  \
# 0       36720410  10001.0   7953.0  10398.0    2.0  4925.0  1999-01-04
# 1       36720410  10001.0   7953.0  10398.0    2.0  4925.0  1999-01-05
# 2       36720410  10001.0   7953.0  10398.0    2.0  4925.0  1999-01-06
# 3       36720410  10001.0   7953.0  10398.0    2.0  4925.0  1999-01-07
# 4       36720410  10001.0   7953.0  10398.0    2.0  4925.0  1999-01-08
# ...          ...      ...      ...      ...    ...     ...         ...
# 340541  88160R10  93436.0  53453.0  66252.0    3.0  9999.0  2022-03-25
# 340542  88160R10  93436.0  53453.0  66252.0    3.0  9999.0  2022-03-28
# 340543  88160R10  93436.0  53453.0  66252.0    3.0  9999.0  2022-03-29
# 340544  88160R10  93436.0  53453.0  66252.0    3.0  9999.0  2022-03-30
# 340545  88160R10  93436.0  53453.0  66252.0    3.0  9999.0  2022-03-31
#
#               bidlo        askhi          prc  ...          bid          ask  \
# ...

# %%
data2 = pd.read_parquet("spx_stock_prices.parquet")
# remove all columns with zeroes values in data2
data2
# Out:
#             JAVA_10078  ORCL_10104  MSFT_10107  SDS_10108  AYE_10137  \
# date
# 1999-01-04     90.0625     43.0000     141.000        0.0        0.0
# 1999-01-05     92.5625     44.3125     146.500        0.0        0.0
# 1999-01-06     90.9375     46.3750     151.250        0.0        0.0
# 1999-01-07     89.6875     45.6250     150.500        0.0        0.0
# 1999-01-08     90.8750     46.2500     149.875        0.0        0.0
# ...                ...         ...         ...        ...        ...
# 2022-03-25      0.0000     81.7300     303.680        0.0        0.0
# 2022-03-28      0.0000     83.6000     310.700        0.0        0.0
# 2022-03-29      0.0000     84.2900     315.410        0.0        0.0
# 2022-03-30      0.0000     83.3600     313.860        0.0        0.0
# 2022-03-31      0.0000     82.7300     308.310        0.0        0.0
#
#             TROW_10138  HON_10145  EMC_10147  BEAM_10225  LLTC_10299  ...  \
# ...

# %%
data.columns
# Out:
# Index(['cusip', 'permno', 'permco', 'issuno', 'hexcd', 'hsiccd', 'date',
#        'bidlo', 'askhi', 'prc', 'vol', 'ret', 'bid', 'ask', 'shrout', 'cfacpr',
#        'cfacshr', 'openprc', 'numtrd', 'retx', 'ticker', 'comnam'],
#       dtype='object')

# %%
# Data cleanup

# columns = ["ticker", "comnam", "cusip", "permno", "bid", "ask", "openprc", "prc", "vol", "retx"]
columns = ["ticker", "price"]
price = data[columns]
price = price.dropna(axis=1, how='all')

# %%
price.drop_duplicates().reset_index(drop=True)
# Out:
#      ticker                      comnam
# 0      EGAS                  ENERGY INC
# 1      EGAS             GAS NATURAL INC
# 2      SUNW        SUN MICROSYSTEMS INC
# 3      JAVA        SUN MICROSYSTEMS INC
# 4      ORCL         ORACLE SYSTEMS CORP
# ...     ...                         ...
# 3901     FN                    FABRINET
# 3902   CBOE        C B O E HOLDINGS INC
# 3903   CBOE  C B O E GLOBAL MARKETS INC
# 3904   TSLA            TESLA MOTORS INC
# 3905   TSLA                   TESLA INC
#
# [3906 rows x 2 columns]

# %%
price.to_parquet("ticker_names.parquet")

# %%
data
# Out:
#            cusip   permno   permco   issuno  hexcd  hsiccd       date  \
# 33229   68389X10  10104.0   8045.0  10536.0    1.0  7372.0 2020-01-02
# 33230   68389X10  10104.0   8045.0  10536.0    1.0  7372.0 2020-01-03
# 33231   68389X10  10104.0   8045.0  10536.0    1.0  7372.0 2020-01-06
# 33232   68389X10  10104.0   8045.0  10536.0    1.0  7372.0 2020-01-07
# 33233   68389X10  10104.0   8045.0  10536.0    1.0  7372.0 2020-01-08
# ...          ...      ...      ...      ...    ...     ...        ...
# 340541  88160R10  93436.0  53453.0  66252.0    3.0  9999.0 2022-03-25
# 340542  88160R10  93436.0  53453.0  66252.0    3.0  9999.0 2022-03-28
# 340543  88160R10  93436.0  53453.0  66252.0    3.0  9999.0 2022-03-29
# 340544  88160R10  93436.0  53453.0  66252.0    3.0  9999.0 2022-03-30
# 340545  88160R10  93436.0  53453.0  66252.0    3.0  9999.0 2022-03-31
#
#               bidlo        askhi          prc  ...          bid          ask  \
# ...
